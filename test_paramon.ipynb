# %%
import random
import csv

# %%
def create_effects(filename,table):
    with open('paramon.csv') as file:
        csv_reader = csv.reader(file, delimiter=',')
        for row in csv_reader:
            effect_table.append(row)
    return(effect_table)
    
def starting_effects(table,effects,used):
    for x in range(0,8):
        effects.append(table[x])
        used.append(table[x])
    del table[0:8]
    return(table,effects,used)

def new_round(table,effects,used):
    index1 = random.randrange(len(effects))
    active_effect = effects[index1]
    print(active_effect)
    effects[index1] = table[0]
    
    del table[0]
    return(table,effects,active_effect,used)

# %%
effect_table = []
effect_set = []
used_effects = []

# %%
effect_table = create_effects('paramon.csv',effect_table)
print(len(effect_table))
# Out:
# 59

# %%
random.shuffle(effect_table)

starting_effects(effect_table,effect_set)
print("Your starting effects are: ")
for stat in effect_set:
    print(stat[1])
# Out:
# Your starting effects are:
# Ex Libris
# I Spy
# Codename
# Spelling Bee
# Inventory
# Procrastinate
# TPS Report
# Going Riley Mode

# %%
new_round(effect_table,effect_set)
print("Your new set of effects are: " + str(effect_set))
print ("There are " + str(len(effect_table)) + " effects remaining.")
# Out:
# ['38', 'I Spy', 'One human and one digimon player both write down the name of a nearby digimon who is not Paramon. If they write the same name, Paramon can give that digimon an extra D10 on their next turn.']
# Your new set of effects are: [['32', 'Ex Libris', 'Rename the discord call "PARAMON\'S REALLY FLY DISCORD CALL"'], ['7', '2 of them', 'If there are exactly 2 cats visible in the background of the discord call, Paramon may attack twice this turn.'], ['35', 'Treble Jig', 'Paramon does a jaunty little number, accompanied by accordion music or a fiddle or something.'], ['42', 'Spelling Bee', '*BEFORE YOU READ THIS OUT LOUD, ask Jake or Christina for a good word. If the other can spell that word, add a D4 to the accuracy roll of your attack'], ['39', 'Inventory', 'Go around the group and do a can check. If nobody has a beverage, subtract a d4 from the accuracy roll for your next attack'], ['5', 'Procrastinate', 'Past Ann and Annie bully their current selves. Roll a d2, 1 for Ann and 2 for Annie. The winner of the roll has to make up a secondary effect on the spot, math and everything.'], ['40', 'TPS Report', 'Paramon is composed of extremely long and incredibly boring documents. Paramon grows to giant size and takes the skill???'], ['20', 'Going Riley Mode', "I have asked a subject matter expert, Riley, to provide input. Bind, Force, Stun, Superficial, Melee. I'm vibing with a mass stun and bind, making the enemy lose two turns and changing their position/throwing them off a cliff. Paramon absolutely breaks the game at one target."]]
# There are 49 effects remaining.
